# %%
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True

# %%
plt.figure()
plt.title(r'Test: $\alpha > \beta$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Tanmay Singh\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\texmanager.py:255, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     254 try:
# --> 255     report = subprocess.check_output(
#     256         command, cwd=cwd if cwd is not None else cls.texcache,
#     257         stderr=subprocess.STDOUT)
#     258 except FileNotFoundError as exc:
#
# File c:\Users\Tanmay Singh\AppData\Local\Programs\Python\Python310\lib\subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# ...
